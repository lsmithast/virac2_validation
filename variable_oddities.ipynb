# %% [markdown]
# # Variable Oddities
# Here I'll store interesting lightcurves I encounter while validating the catalogue.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# import some general virac v2 lightcurve tools
from wsdb_lc import *

# we'll be doing a lot of plotting lightcurves, may as well make it a function
def plot_lc(sourceid, xlims=(2010,2019)):
    lc = LightCurve(sourceid)
    lc.to_years()
    plt.figure(figsize=(12,3))
    plt.errorbar(lc.t, lc.mag, yerr=lc.emag,
                 fmt='.', markersize=3, linewidth=1, capsize=2)
    plt.xlabel("t  /  %s" % lc.t_unit)
    plt.ylabel("K$_s$  /  mag")
    plt.xlim(*xlims)
    plt.gca().invert_yaxis()
    plt.grid()
    plt.tight_layout()

# %% [markdown]
# ## Unknown

# %% [markdown]
# #### 652506075580
# 'Fader'? See e.g. VVVv316 of Contreras Pena et al. 2016 (Fig. 4).

# %%
plot_lc(652506075580)

# %% [markdown]
# ## Novae

# %% [markdown]
# #### 558322030688

# %%
plot_lc(558322030688)

# %% [markdown]
# #### 604403104362

# %%
plot_lc(604403104362)

# %% [markdown]
# #### 602347080781

# %%
plot_lc(602347080781)

# %% [markdown]
# ## Microlensing

# %% [markdown]
# #### 616681051474
# probable microlensing

# %%
plot_lc(616681051474)

# %%
plot_lc(616681051474, (2011,2014))

# %% [markdown]
# #### 615660093663

# %%
plot_lc(615660093663)

# %%
plot_lc(615660093663, (2014,2016))

# %% [markdown]
# #### 609515065873

# %%
plot_lc(609515065873)

# %% [markdown]
# #### 603368078739

# %%
plot_lc(603368078739)

# %% [markdown]
# #### 606442036590

# %%
plot_lc(606442036590)

# %% [markdown]
# #### 604393016032
# ...so many microlensing candidates!

# %%
plot_lc(604393016032)

# %% [markdown]
# #### 624879041112

# %%
plot_lc(624879041112)

# %% [markdown]
# #### 623852043262

# %%
plot_lc(623852043262)

# %% [markdown]
# ## Dwarf Novae

# %% [markdown]
# #### 605403049549
# This is a known dwarf nova [simbad](http://simbad.u-strasbg.fr/simbad/sim-id?Ident=%402380218&Name=V*%20FQ%20Sco&submit=submit)

# %%
plot_lc(605403049549)
